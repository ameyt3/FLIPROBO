# %% [markdown]
# importing the necessary libraries

# %%
import pandas as pd
from selenium import webdriver
import time
from selenium.webdriver.common.keys import Keys

# %% [markdown]
# # q1 and q2 searching specific product in amazon and scraping the required data

# %%
driver=webdriver.Chrome(r'Chromedriver.exe')
#navigating to URL
driver.get('https://www.amazon.in/')
product=input('enter product to be searched')
driver.find_element_by_xpath('//input[@id="twotabsearchtextbox"]').send_keys(str(product))
driver.find_element_by_xpath('//input[@id="nav-search-submit-button"]').click()
time.sleep(5)
brand=[]
name=[]
rating=[]
no_of_ratings=[]
price=[]
ret_exc=[]
exp_del=[]
availability=[]
oth_det=[]
url_prod=[]
urls=[]
j=0
#scraping the urls for products
while j<3:
    time.sleep(5)
    url_tags=driver.find_elements_by_xpath('//a[@class="a-link-normal a-text-normal"]')
    for i in url_tags:
        urls.append(i.get_attribute('href'))
    driver.find_element_by_xpath('//li[@class="a-last"]').click()
    j+=1
#scraping data for each product
for url in urls:
    driver.get(url)
    name.append(driver.find_element_by_xpath('//span[@id="productTitle"]').text)
    try:
        rating.append(driver.find_element_by_xpath('//span[@id="acrPopover"]/span/a/i/span').get_sttribute('title'))
    except:
        rating.append('-')
    try:
        no_of_ratings.append(driver.find_element_by_xpath('//span[@id="acrCustomerReviewText"]').text)
    except:
        no_of_ratings.append('-')
    try:
        price.append(driver.find_element_by_xpath('//span[@id="priceblock_ourprice"]').text)
    except:
        price.append('-')
    try:
        ret_exc.append(driver.find_element_by_xpath('//div[@data-name="RETURNS_POLICY"]').text)
    except:
        ret_exc.append('-')
    try:
        exp_del.append(driver.find_element_by_xpath('//div[@id="ddmDeliveryMessage"]/b').text)
    except:
        exp_del.append('-')
    try:
        availability.append(driver.find_element_by_xpath('//div[@id="availability"]/span').text)
    except:
        availability.append('-')
    url_prod.append(url)
#creating dataframe of acquired data
product_amaz=pd.DataFrame({})
product_amaz['Brand']=brand
product_amaz['Name']=name
product_amaz['Rating']=rating
product_amaz['no_of_ratings']=no_of_ratings
product_amaz['price']=price
product_amaz['ret_exc']=ret_exc
product_amaz['exp_del']=exp_del
product_amaz['availability']=availability
product_amaz['url_prod']=url_prod
product_amaz.head()
# Out:
# enter product to be searchedmonitor
#    Brand                                               Name Rating  \
# 0    NaN  Lenovo 60.4 cm (23.8-inch) FHD Ultra Slim Near...      -
# 1    NaN  Lenovo L24e-20, 23.8-inch Near Edgeless Monito...      -
# 2    NaN  Lenovo 54.6 cm (21.5 inch) Near Edgeless Monit...      -
# 3    NaN  Samsung 59.8 cm (23.5 inch) Curved LED Backlit...      -
# 4    NaN  LG 22 inch (55cm) IPS Monitor - Full HD, IPS P...      -
#
#    no_of_ratings        price             ret_exc            exp_del  \
# 0    101 ratings  ₹ 12,599.00  7 Days Replacement     Tuesday, Feb 9
# 1    100 ratings   ₹ 9,000.00  7 Days Replacement     Tuesday, Feb 9
# 2    344 ratings   ₹ 6,990.00  7 Days Replacement  Wednesday, Feb 10
# 3  3,664 ratings   ₹ 9,215.00  7 Days Replacement     Tuesday, Feb 9
# 4  4,541 ratings   ₹ 8,499.00  7 Days Replacement     Tuesday, Feb 9
#
#   availability                                           url_prod
# 0    In stock.  https://www.amazon.in/gp/slredirect/picassoRed...
# 1    In stock.  https://www.amazon.in/gp/slredirect/picassoRed...
# 2    In stock.  https://www.amazon.in/Lenovo-L22e-20-Monitor-D...
# 3    In stock.  https://www.amazon.in/Samsung-23-5-inch-Curved...
# 4    In stock.  https://www.amazon.in/LG-inch-55cm-LCD-Monitor...

# %% [markdown]
# # q3 search image results for ‘fruits’, ‘cars’ and ‘Machine Learning’.

# %%
driver=webdriver.Chrome(r'Chromedriver.exe')
img_fruit=[]
img_cars=[]
ML=[]
for search in ['fruits','cars','Machine Learning']:
    driver.get('https://images.google.com/')
    driver.find_element_by_xpath('//input[@class="gLFyf gsfi"]').send_keys(search)
    driver.find_element_by_xpath('//div[@class="FAuhyb"]').click()
    time.sleep(5)
    tags1=driver.find_elements_by_xpath('//img[@class="rg_i Q4LuWd"]')
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(2)
    tags2=driver.find_elements_by_xpath('//img[@class="rg_i Q4LuWd"]')
    tags=tags1+tags2
    if search=='fruits':
        for i in tags:
            img_fruit.append(i.get_attribute('src'))
    elif search=='cars':
        for i in tags:
            img_cars.append(i.get_attribute('src'))
    else:
        for i in tags:
            ML.append(i.get_attribute('src'))
images=pd.DataFrame({})
images['Fruit_Images']=img_fruit[0:100]
images['Car_Images']=img_cars[0:100]
images['ML_images']=ML[0:100]
images.head()
# Out:
#                                         Fruit_Images  \
# 0  ......
# 1  ......
# 2  ......
# 3  ......
# 4  ......
#
#                                           Car_Images  \
# 0  ......
# 1  ......
# 2  ......
# 3  ......
# 4  ......
#
#                                            ML_images
# 0  ......
# 1  ......
# 2  ......
# 3  ......
# 4  ......

# %% [markdown]
# # q5 get coordinates for location accepted as input

# %%
def loc_fun():
    
    driver=webdriver.Chrome(r'Chromedriver.exe')
    driver.get('https://www.google.com/maps')
    driver.maximize_window()
    loc=input('enter location')
    driver.find_element_by_xpath('//input[@id="searchboxinput"]').send_keys(str(loc))
    driver.find_element_by_xpath('//button[@id="searchbox-searchbutton"]').click()
    time.sleep(5)
    url_str=driver.current_url
    if '@' in url_str:
        index_a=url_str.index('@')
        print('co-ordinates are',url_str[index_a+1:index_a+20])

# %%
loc_fun()
# Out:
# enter locationdapoli
# co-ordinates are 17.7667305,73.17991

# %% [markdown]
# # q7 laptop details from digit.in

# %%
driver=webdriver.Chrome(r'Chromedriver.exe')
driver.get('https://www.digit.in/')
driver.maximize_window()
time.sleep(3)
driver.find_element_by_xpath('//div[@class="menu"]/ul/li[3]/a').click()
time.sleep(3)
driver.find_element_by_xpath('//div[@class="listing_container"]/ul/li[26]/a').click()
title=[]
OS=[]
display=[]
processor=[]
memory=[]
weight=[]
dimension=[]
graphic=[]
price=[]
titles=driver.find_elements_by_xpath('//div[@class="right-container"]/div/a/h3')
for i in titles:
    title.append(i.text)
os_tags=driver.find_elements_by_xpath('//div[@class="Spcs-details"]/table/tbody/tr[3]/td[3]')
for i in os_tags:
    OS.append(i.text)
displays=driver.find_elements_by_xpath('//div[@class="Spcs-details"]/table/tbody/tr[4]/td[3]')
for i in displays:
    display.append(i.text)
processors=driver.find_elements_by_xpath('//div[@class="Spcs-details"]/table/tbody/tr[5]/td[3]')
for i in processors:
    processor.append(i.text)
memories=driver.find_elements_by_xpath('//div[@class="Spcs-details"]/table/tbody/tr[6]/td[3]')
for i in memories:
    memory.append(i.text)
weights=driver.find_elements_by_xpath('//div[@class="Spcs-details"]/table/tbody/tr[7]/td[3]')
for i in weights:
    weight.append(i.text)
dimensions=driver.find_elements_by_xpath('//div[@class="Spcs-details"]/table/tbody/tr[8]/td[3]')
for i in dimensions:
    dimension.append(i.text)
graphics=driver.find_elements_by_xpath('//div[@class="Spcs-details"]/table/tbody/tr[9]/td[3]')
for i in graphics:
    graphic.append(i.text)
#price_urls=[]
#full_specs=driver.find_elements_by_xpath('//div[@class="full-specs"]/span')
#for i in full_specs:
#    price_urls.append(i.get_attribute('data-href'))
#for i in price_urls:
#    driver.get(str(i))
#    time.sleep(3)
#    price.append(driver.find_element_by_xpath('//div[@class="Onward-price"]/div/b').text)
laptops=pd.DataFrame({})
laptops['Title']=title
laptops['OS']=OS
laptops['Display']=display
laptops['Processor']=processor
laptops['Memory']=memory
laptops['Weight']=weight
laptops['Dimension']=dimension
laptops['Graphic']=graphic
laptops.head()
# Out:
#                    Title               OS                    Display  \
# 0  MSI GT76 TITAN DT 9SG   Windows 10 Pro      17.3" (UHD 3840x2160)
# 1  ALIENWARE 17 AREA-51M   Windows 10 Pro  17.3" (FHD (1920 x 1080))
# 2        HP OMEN 15 2020  Windows 10 Home        15.6" (1920 x 1080)
# 3      ASUS ZEPHYRUS G14  Windows 10 Home          14" (1920 x 1080)
# 4     LENOVO LEGION Y540  Windows 10 Home        15.6" (1920 X 1080)
#
#                                       Processor                   Memory  \
# 0        Intel 9th Gen Core i9-9900K | 5000 MHz    1 TB HDD/64 GBGB DDR4
# 1        Intel 9th Gen Core i9-9900K | 5000 MHz  1 TB PCIe SSD/32GB DDR4
# 2             Intel i7-10750H 10th Gen | 1.6GHz  512 GB SSD/16 GBGB DDR4
# 3          AMD 3rd Generation Ryzen 9 | 3.3 GHz    1 TB SSD/16 GBGB DDR4
# 4  9th Generation Core Intel I7-9750H | 2.6 Ghz        1 TB SSD/8GB DDR4
#
#     Weight                     Dimension                    Graphic
# 0   4.2 kg          397 x 330 x 33~42 mm    NVIDIA GeForce RTX 2080
# 1  3.87 Kg  42 mm x 402.6 mm x 319.14 mm    NVIDIA GeForce RTX 2080
# 2     5.40           14.09 x 9.44 x 0.89  Nvidia GeForce GTX 1650Ti
# 3     1.65             32.5 x 22.1 x 1.8    NVIDIA GeForce RTX 2060
# 4      2.3        365mm x 260mm x 25.9mm  NVIDIA® GeForce RTX™ 2060

# %%
driver=webdriver.Chrome(r'Chromedriver.exe')
driver.get('https://www.flipkart.com/')
product=input('enter product to be searched')
driver.find_element_by_xpath('//button[@class="_2KpZ6l _2doB4z"]').click()
time.sleep(3)
driver.find_element_by_xpath('//input[@title="Search for products, brands and more"]').send_keys(str(product))
driver.find_element_by_xpath('//button[@type="submit"]').click()
time.sleep(4)
urls=[]
brand=[]
name=[]
color=[]
RAM=[]
ROM=[]
prim_cam=[]
sec_cam=[]
display_size=[]
display_res=[]
processor=[]
processor_core=[]
battery=[]
price=[]
links=driver.find_elements_by_xpath('//a[@class="_1fQZEK"]')
for i in links:
    urls.append(i.get_attribute('href'))
for i in urls:
    driver.get(i)
    time.sleep(3)
    driver.find_element_by_xpath('//button[@class="_2KpZ6l _1FH0tX"]').click()
    try:
        title=driver.find_element_by_xpath('//span[@class="B_NuCI"]').text.split()
        brand.append(title[0])
    except:
        brand.append('-')
    try:
        name.append(driver.find_element_by_xpath('//div[@class="_1UhVsV"]/div[1]/table/tbody/tr[3]/td[2]').text)
    except:
        name.append('-')
    try:
        color.append(driver.find_element_by_xpath('//div[@class="_1UhVsV"]/div[1]/table/tbody/tr[4]/td[2]').text)
    except:
        color.append('-')
    try:
        RAM.append(driver.find_element_by_xpath('//div[@class="_1UhVsV"]/div[4]/table/tbody/tr[2]/td[2]').text)
    except:
        RAM.append('-')
    try:
        ROM.append(driver.find_element_by_xpath('//div[@class="_1UhVsV"]/div[4]/table/tbody/tr[1]/td[2]').text)
    except:
        ROM.append('-')
    try:
        prim_cam.append(driver.find_element_by_xpath('//div[@class="_1UhVsV"]/div[5]/table/tbody/tr[2]/td[2]').text)
    except:
        prim_cam.append('-')
    try:
        sec_cam.append(driver.find_element_by_xpath('//div[@class="_1UhVsV"]/div[5]/table/tbody/tr[5]/td[2]').text)
    except:
        sec_cam.append('-')
    try:
        display_size.append(driver.find_element_by_xpath('//div[@class="_1UhVsV"]/div[2]/table/tbody/tr[1]/td[2]').text)
    except:
        display_size.append('-')
    try:
        display_res.append(driver.find_element_by_xpath('//div[@class="_1UhVsV"]/div[2]/table/tbody/tr[2]/td[2]').text)
    except:
        display_res.append('-')
    try:
        processor.append(driver.find_element_by_xpath('//div[@class="_1UhVsV"]/div[3]/table/tbody/tr[2]/td[2]').text)
    except:
        processor.append('-')
    try:
        processor_core.append(driver.find_element_by_xpath('//div[@class="_1UhVsV"]/div[3]/table/tbody/tr[3]/td[2]').text)
    except:
        processor_core.append('-')
    try:
        battery.append(driver.find_element_by_xpath('//div[@class="_1UhVsV"]/div[10]/table/tbody/tr[1]/td[2]').text)
    except:
        battery.append('-')
    try:
        price.append(driver.find_element_by_xpath('//div[@class="dyC4hf"]/div/div/div').text)
    except:
        price.append('-')
    
flip_search=pd.DataFrame({})
flip_search['brand']=brand
flip_search['name']=name
flip_search['color']=color
flip_search['RAM']=RAM
flip_search['ROM']=ROM
flip_search['prim_cam']=prim_cam
flip_search['sec_cam']=sec_cam
flip_search['display_size']=display_size
flip_search['display_res']=display_res
flip_search['processor']=processor
flip_search['processor_core']=processor_core
flip_search['battery']=battery
flip_search['price']=price
flip_search['urls']=urls
flip_search
# Out:
# enter product to be searchedpixel
#         brand                  name               color    RAM     ROM  \
# 0      Google              Pixel 4a          Just Black   6 GB  128 GB
# 1      Google              Pixel 3a       Clearly White   4 GB   64 GB
